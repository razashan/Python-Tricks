# %%
import os 
folder_dict = {}
path = 'validation/'

for root,dirs,files in os.walk(path): 
    for d in dirs:
        folder_dict[d] = len(os.listdir(os.path.join(root, d))) 
for key,value in folder_dict.items(): 
    print(key,':', value)
# Out:
# 3076bc5e : 1
# adagent : 0
# agentb : 8
# alphabet : 1
# ambler : 0
# antavmu : 2
# archsms : 14
# awfckfni : 1
# badbar : 1
# baigoo : 0
# banjori : 1
# batchdrop : 1
# beastdoor : 3
# behav : 0
# bestafera : 2
# bifrose : 20
# bitrep : 2
# blohi : 0
# bmmedia : 2
# bodsuds : 0
# bototer : 1
# browsefox : 150
# bwkk : 1
# cakl : 2
# calac : 5
# calper : 3
# cckrizcry : 10
# ceatrg : 2
# chadpush : 3
# cheatengine : 1
# chir : 10
# cnbtech : 0
# cybergate : 1
# dapato : 1
# dbjustping : 1
# dealply : 0
# decfile : 1
# delbar : 0
# delf : 151
# desurou : 0
# dgtsoft : 1
# dial : 23
# dialupass : 1
# directdownloader : 4
# dlhelper : 28
# dollarr : 0
# dorgam : 1
# dybalom : 1
# dycler : 0
# emogen : 2
# eruwbi : 0
# eupuds : 0
# exebinder : 1
# exebundle : 0
# expkit : 3
# explorerhijack : 0
# expressdownloader : 3
# eyestye : 3
# fbjack : 2
# fenomengame : 36
# fesber : 33
# flashapp : 0
# forcestartpage : 20
# fosniw : 32
# frethoq : 14
# genericrxen : 0
# generictka : 8
# ...

# %%
count = []
filname = []
for i in folder_dict:
    filname.append(i)
for j in folder_dict.values():
    count.append(j)

# %%
df = pd.DataFrame(list(zip(filname,count)),columns = ["Filename","Count"])

# %%
df.head()
# Out:
#    Filename  Count
# 0  3076bc5e      1
# 1   adagent      0
# 2    agentb      8
# 3  alphabet      1
# 4    ambler      0

# %%
df.to_csv("Prep_Data.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 15

fig = plt.figure(figsize=(32,8))
ax =sns.barplot(x='Filename', y='Count', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.set_context("notebook", font_scale=1.5)
